# %%
import pandas as pd
dfp = pd.read_csv('https://raw.githubusercontent.com/Esther-Velasco/mid_term_project/main/4_countries_wage.csv', sep=',',skiprows=3)
dfp
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
# 1    Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
# 2    Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
# 3    Wage and salaried workers, total (% of total e...  SL.EMP.WORK.ZS   NaN
# ...

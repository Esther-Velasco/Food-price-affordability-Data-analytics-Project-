# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Esther-Velasco/mid_term_project/main/wfp_market_food_prices.csv', sep=',', encoding='latin-1')
df.tail(50)
# Out:
#         adm0_id    adm0_name  adm1_id          adm1_name  mkt_id mkt_name  \
# 743864    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743865    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743866    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743867    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743868    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743869    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743870    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743871    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743872    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743873    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743874    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# 743875    70001  South Sudan     2750  Eastern Equatoria    1786    Torit
# ...
